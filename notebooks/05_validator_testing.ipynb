# %% [markdown]
# ## 1. Imports
#
# We inject the project root into the system path to allow importing our custom `DataValidator` module and standard libraries.

# %%
import pandas as pd
from pathlib import Path
import sys

current_dir = Path.cwd()
PROJECT_ROOT = current_dir.parent if current_dir.name == "notebooks" else current_dir

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.etl.validator import DataValidator

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# ## 2. Project Paths
#
# Establish absolute paths for our raw data and reporting directories.

# %%
DATA = PROJECT_ROOT / "data" / "raw"
REPORT = PROJECT_ROOT / "reports"
REPORT.mkdir(exist_ok=True)

print(f"Raw Data Path: {DATA}")
# Out:
# Raw Data Path: c:\Users\polai\OneDrive\Desktop\N100 FINANCIAL INTELLIGENCE PLATFORM\nifty100-financial-intelligence-platform\data\raw

# %% [markdown]
# ## 3. Load Dataset
#
# Load the master `companies.xlsx` dataset to serve as our primary validation test subject.

# %%
file = DATA / "companies.xlsx"
df = pd.read_excel(file)

display(df.head())
# Out:
#   Mkt Fintech — Nifty 100  |  Companies  |  92 records  \
# 0                                                 id
# 1                                                ABB
# 2                                         ADANIENSOL
# 3                                           ADANIENT
# 4                                         ADANIGREEN
#
#                                           Unnamed: 1  \
# 0                                       company_logo
# 1   https://mkt.in/static/mkt-icons/nifty100/ABB.png
# 2  https://m.economictimes.com/thumb/msid-1173715...
# 3  https://mkt.in/static/mkt-icons/nifty100/ADANI...
# 4  https://mkt.in/static/mkt-icons/nifty100/ADANI...
#
#                    Unnamed: 2  \
# 0                company_name
# 1            Abbott India Ltd
# 2  Adani Energy Solutions Ltd
# 3       Adani Enterprises Ltd
# 4      Adani Green Energy Ltd
#
#                                           Unnamed: 3  \
# 0                                         chart_link
# 1  https://in.tradingview.com/chart/?symbol=NSE%3...
# 2  https://in.tradingview.com/chart/?symbol=NSE%3...
# 3  https://in.tradingview.com/chart/?symbol=ADANIENT
# 4  https://in.tradingview.com/chart/?symbol=NSE%3...
#
#                                           Unnamed: 4  \
# 0                                      about_company
# 1  Abbott India Ltd is one of the leading multina...
# 2  AESL, part of the Adani portfolio, is a multid...
# 3  Adani Enterprises Ltd is an Indian multination...
# 4  Adani Green Energy Limited, incorporated in 20...
#
#                               Unnamed: 5  \
# 0                                website
# 1              https://www.abbott.co.in/
# 2  https://www.adanienergysolutions.com/
# 3      https://www.adanienterprises.com/
# 4       http://www.adanigreenenergy.com/
#
#                                           Unnamed: 6  \
# 0                                        nse_profile
# 1  https://www.nseindia.com/get-quotes/equity?sym...
# 2  https://www.nseindia.com/get-quotes/equity?sym...
# 3  https://www.nseindia.com/get-quotes/equity?sym...
# 4  https://www.nseindia.com/get-quotes/equity?sym...
#
#                                           Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                                        bse_profile  face_value  book_value
# 1  https://www.bseindia.com/stock-share-price/abb...          10        1657
# 2  https://www.bseindia.com/stock-share-price/ada...          10         175
# 3  https://www.bseindia.com/stock-share-price/ada...           1         363
# 4  https://www.bseindia.com/stock-share-price/ada...          10          67
#
#        Unnamed: 10     Unnamed: 11
# 0  roce_percentage  roe_percentage
# 1               46            34.9
# 2                9            8.59
# 3             11.6           13.64
# 4             96.5            14.7

# %% [markdown]
# ## 4. Run Validator
#
# Instantiate our advanced `DataValidator` class and execute the validation pipeline across the dataset. This triggers rules for empty sets, duplicate columns/rows, missing values, date ranges, and URL patterns.

# %%
validator = DataValidator()

# Execute the validation rules
df = validator.validate(df, "companies")

print("Validation rules applied successfully.")
# Out:
# Validation rules applied successfully.

# %% [markdown]
# ## 5. Review Validation Report
#
# Fetch and display the high-level summary report of all validation checks performed.

# %%
report = validator.get_report()
display(report)
# Out:
#       Dataset                     Rule Severity Status                Details
# 0   companies      DQ-00 Empty Dataset     INFO   PASS  Dataset contains data
# 1   companies  DQ-05 Duplicate Columns     INFO   PASS   No duplicate columns
# 2   companies     DQ-04 Duplicate Rows     INFO   PASS      No duplicate rows
# 3   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 1: 1
# 4   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 5: 1
# 5   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 6: 1
# 6   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 7: 1
# 7   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 8: 1
# 8   companies     DQ-03 Missing Values  WARNING   FAIL          Unnamed: 9: 1
# 9   companies     DQ-03 Missing Values  WARNING   FAIL         Unnamed: 10: 1
# 10  companies     DQ-03 Missing Values  WARNING   FAIL         Unnamed: 11: 2

# %% [markdown]
# ## 6. Review Failures
#
# Fetch and display specific failure instances (like missing values, duplicate rows, or malformed URLs) caught by our strict rules.

# %%
failures = validator.get_failures()
display(failures)
# Out:
#      Dataset       Column            Rule Value Severity
# 0  companies   Unnamed: 1  Missing Values  NULL  WARNING
# 1  companies   Unnamed: 5  Missing Values  NULL  WARNING
# 2  companies   Unnamed: 6  Missing Values  NULL  WARNING
# 3  companies   Unnamed: 7  Missing Values  NULL  WARNING
# 4  companies   Unnamed: 8  Missing Values  NULL  WARNING
# 5  companies   Unnamed: 9  Missing Values  NULL  WARNING
# 6  companies  Unnamed: 10  Missing Values  NULL  WARNING
# 7  companies  Unnamed: 11  Missing Values  NULL  WARNING

# %% [markdown]
# ## 7. Export Reports
#
# Persist our data quality findings to CSV files inside the `/reports` directory for review by data engineering teams.

# %%
if not report.empty:
    report.to_csv(REPORT / "validation_report.csv", index=False)

if not failures.empty:
    failures.to_csv(REPORT / "validation_failures.csv", index=False)

print("Reports Generated and Saved to Disk!")
# Out:
# Reports Generated and Saved to Disk!
